# %% [markdown]
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。
#
#
#
# 請點擊下方檢視範例參考Day010_Sample.ipynb，作業請提交Day010_HW.ipynb

# %%
from grab import Grab
g=Grab()
resp=g.go('https://google.com')
resp.body
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-159ea7898631> in <module>
# ----> 1 from grab import Grab
#       2 g=Grab()
#       3 resp=g.go('https://google.com')
#       4 resp.body
#
# ModuleNotFoundError: No module named 'grab'

# %%
# !pip install grab
# Out:
# Collecting grab
#   Downloading https://files.pythonhosted.org/packages/26/87/c0b939da311bed38c0c073fd61675cfbe4ba585c2a04370a5b7e106a2639/grab-0.6.41.tar.gz (1.1MB)
# Collecting weblib>=0.1.28 (from grab)
#   Downloading https://files.pythonhosted.org/packages/67/16/2761dab6e8515708a2762dc34e6b8e089df21211d98f91d298911f2fd5b0/weblib-0.1.30.tar.gz
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from grab) (1.12.0)
# Collecting user_agent (from grab)
#   Downloading https://files.pythonhosted.org/packages/c3/ca/15546284f62edfec7666ecb6403a6e77f5db850def37cd36f140d99cce02/user_agent-0.1.9.tar.gz
# Collecting selection (from grab)
#   Downloading https://files.pythonhosted.org/packages/32/01/7e9f093e502c3b19d8fd8c7046de31534a0254bb6aaced0403739dc7f704/selection-0.0.14.tar.gz
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from grab) (0.6.0)
# Collecting pytils (from weblib>=0.1.28->grab)
#   Downloading https://files.pythonhosted.org/packages/c6/c1/12b556b5bb393ce5130d57af862d045f57fee764797c0fe837e49cb2a5da/pytils-0.3.tar.gz (89kB)
# Building wheels for collected packages: grab, weblib, user-agent, selection, pytils
#   Building wheel for grab (setup.py): started
#   Building wheel for grab (setup.py): finished with status 'done'
#   Created wheel for grab: filename=grab-0.6.41-cp37-none-any.whl size=84701 sha256=5cf7ffc279654c55b39c78dd435e8f135d1c400d44bcf293384476d32d292eac
#   Stored in directory: C:\Users\User\AppData\Local\pip\Cache\wheels\84\ff\2d\08f71c11e5b73027dfa7d1ac8bd654b60af2df57ae89bd29d5
#   Building wheel for weblib (setup.py): started
#   Building wheel for weblib (setup.py): finished with status 'done'
#   Created wheel for weblib: filename=weblib-0.1.30-cp37-none-any.whl size=40161 sha256=14f85e1f823718c056489c26e5a2e872da52686e011d2c432fc3fa32d43efa86
#   Stored in directory: C:\Users\User\AppData\Local\pip\Cache\wheels\4d\92\d1\f89cbbefae35442b82a069a60f6b596c77f22ab5d58813e4a4
#   Building wheel for user-agent (setup.py): started
#   Building wheel for user-agent (setup.py): finished with status 'done'
#   Created wheel for user-agent: filename=user_agent-0.1.9-cp37-none-any.whl size=18812 sha256=5453e3ae1417339383a75cf65c5a1a81f66a32adea830cf289bfbcf57649a1c6
#   Stored in directory: C:\Users\User\AppData\Local\pip\Cache\wheels\92\80\3f\5d79277825042f2d4d447f594e3fc046f1e506f2b481d364b2
#   Building wheel for selection (setup.py): started
#   Building wheel for selection (setup.py): finished with status 'done'
#   Created wheel for selection: filename=selection-0.0.14-cp37-none-any.whl size=5365 sha256=29607eef83ffc6b162430206632f26865c583e285925f16be65b1525e8016491
#   Stored in directory: C:\Users\User\AppData\Local\pip\Cache\wheels\f6\78\ea\df9f78c9f3fb643b9fc9f6e70fab990e5f8455024d34019418
#   Building wheel for pytils (setup.py): started
#   Building wheel for pytils (setup.py): finished with status 'done'
#   Created wheel for pytils: filename=pytils-0.3-cp37-none-any.whl size=40360 sha256=981cf3c281ec46f184a3cbdcecb1d5433cd796a34e5ed0e531d30ca581f4a112
#   Stored in directory: C:\Users\User\AppData\Local\pip\Cache\wheels\d6\f9\dc\4f07d8ee40d9cfca9973b3f4aeff99d0bb69900e5f3dffbf32
# Successfully built grab weblib user-agent selection pytils
# Installing collected packages: pytils, user-agent, weblib, selection, grab
# Successfully installed grab-0.6.41 pytils-0.3 selection-0.0.14 user-agent-0.1.9 weblib-0.1.30

# %%
# -*- coding: utf-8 -*-
from grab import Grab
from pyquery import PyQuery as pq
g=Grab()
resp=g.go('https://www.dcard.tw/f',encoding='utf-8')
pq('https://www.dcard.tw/f',encoding='utf-8')
resp.body
# Out:
# b'\n  <!DOCTYPE html>\n  <html lang="zh-tw">\n    <head>\n      <meta charset="UTF-8">\n      <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n      <meta http-equiv="X-UA-Compatible" content="ie=edge">\n      <meta name="theme-color" content="#006aa6">\n      <meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" property="og:site_name" content="Dcard"/><meta data-react-helmet="true" property="og:title" content="\xe5\x85\xa8\xe9\x83\xa8 \xc2\xa0| Dcard"/><meta data-react-helmet="true" property="og:url" content="https://www.dcard.tw/f"/><meta data-react-helmet="true" name="twitter:title" content="\xe5\x85\xa8\xe9\x83\xa8 | Dcard"/><meta data-react-helmet="true" property="al:ios:url" content="dcard://category/all/\xe5\x85\xa8\xe9\x83\xa8/hot"/><meta data-react-helmet="true" property="al:android:url" content="dcard://category/all/\xe5\x85\xa8\xe9\x83\xa8/hot"/>\n      <title data-react-helmet="true">\xe5\x85\xa8\xe9\x83\xa8 | Dcard</title>\n      <link data-react-helmet="true" rel="canonical" href="https://www.dcard.tw/f"/>\n      <link rel="manifest" href="/build//manifest.json">\n      <link rel=\'icon\' sizes=\'32x32\' type=\'image/png\' href="/build//images/favicon_32.png"/>\n      <link rel=\'icon\' sizes=\'72x72\' type=\'image/png\' href="/build//images/favicon_72.png"/>\n      <link rel=\'icon\' sizes=\'512x512\' type=\'image/png\' href="/build//images/favicon_512.png"/>\n\n      <link rel=\'apple-touch-icon-precomposed\' size=\'144x144\' href="/build//images/favicon_144.png"/>\n      <link rel=\'apple-touch-icon-precomposed\' size=\'114x114\' href="/build//images/favicon_114.png"/>\n      <link rel=\'apple-touch-icon-precomposed\' size=\'72x72\' href="/build//images/favicon_72.png"/>\n      <link rel=\'apple-touch-icon-precomposed\' href="/build//images/favicon_57.png"/>\n\n      \n<script>\n(function(e,t){var n=e.amplitude||{_q:[],_iq:{}};var r=t.createElement("script")\n;r.type="text/javascript";r.async=true\n;r.src="https://cdn.amplitude.com/libs/amplitude-4.4.0-min.gz.js"\n;r.onload=function(){if(e.amplitude.runQueuedFunctions){\ne.amplitude.runQueuedFunctions()}else{\nconsole.log("[Amplitude] Error: could not load SDK")}}\n;var i=t.getElementsByTagName("script")[0];i.parentNode.insertBefore(r,i)\n;function s(e,t){e.prototype[t]=function(){\nthis._q.push([t].concat(Array.prototype.slice.call(arguments,0)));return this}}\nvar o=function(){this._q=[];return this}\n;var a=["add","append","clearAll","prepend","set","setOnce","unset"]\n;for(var u=0;u<a.length;u++){s(o,a[u])}n.Identify=o;var c=function(){this._q=[]\n;return this}\n;var l=["setProductId","setQuantity","setPrice","setRevenueType","setEventProperties"]\n;for(var p=0;p<l.length;p++){s(c,l[p])}n.Revenue=c\n;var d=["init","logEvent","logRevenue","setUserId","setUserProperties","setOptOut","setVersionName","setDomain","setDeviceId","setGlobalUserProperties","identify","clearUserProperties","setGroup","logRevenueV2","regenerateDeviceId","logEventWithTimestamp","logEventWithGroups","setSessionId","resetSessionId"]\n;function v(e){function t(t){e[t]=function(){\ne._q.push([t].concat(Array.prototype.slice.call(arguments,0)))}}\nfor(var n=0;n<d.length;n++){t(d[n])}}v(n);n.getInstance=function(e){\ne=(!e||e.length===0?"$default_instance":e).toLowerCase()\n;if(!n._iq.hasOwnProperty(e)){n._iq[e]={_q:[]};v(n._iq[e])}return n._iq[e]}\n;e.amplitude=n})(window,document);\n\namplitude.getInstance().init("c618800786141ad91fe6616b7d70ceeb");\n</script>\n\n      \n<script>(function(){var w=window;var ic=w.Intercom;if(typeof ic==="function"){ic(\'reattach_activator\');ic(\'update\',w.intercomSettings)}\nelse{var d=document;var i=function(){i.c(arguments)};i.q=[];i.c=function(args){i.q.push(args)};w.Intercom=i;\nvar l=function(){var s=d.createElement(\'script\');s.type=\'text/javascript\';s.async=true;\ns.src=\'https://widget.intercom.io/widget/nd88a3n4\';\nvar x=d.getElementsByTagName(\'script\')[0 ...

# %%
from pyquery import PyQuery as pq
doc=pq(resp.body)
title=doc('title')
print(type(title),title.text())
# Out:
# <class 'pyquery.pyquery.PyQuery'> Dcard

# %%
# !pip install pyquery
# Out:
# Collecting pyquery
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Collecting cssselect>0.7.9 (from pyquery)
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: lxml>=2.1 in c:\users\user\anaconda3\lib\site-packages (from pyquery) (4.4.1)
# Installing collected packages: cssselect, pyquery
# Successfully installed cssselect-1.1.0 pyquery-1.4.1

# %%
from pyquery import PyQuery as pq
doc=pq(resp.body)
title=doc('title')
print(type(title),title.text())
# Out:
# <class 'pyquery.pyquery.PyQuery'> Dcard
